# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\kunja\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kunja\AppData\Roaming\nltk_data...
# True

# %%
import nltk
from nltk.corpus import wordnet

# Define the input sentence
sentence = input("Enter a sentence: ")

# Tokenize the sentence into words
words = nltk.word_tokenize(sentence)

# Identify the part-of-speech tags for the words
pos_tags = nltk.pos_tag(words)
# Out:
# Enter a sentence: I saw her duck

# %%
for i in pos_tags:
    print(i)
# Out:
# ('I', 'PRP')
# ('saw', 'VBD')
# ('her', 'PRP')
# ('duck', 'NN')

# %%
# Identify the possible meanings for any verbs or nouns with multiple senses
ambiguous_words = {}
for i in range(len(pos_tags)):
    word, pos_tag = pos_tags[i]
    if pos_tag.startswith('V') or pos_tag.startswith('N'):
        meanings = set()
        for synset in wordnet.synsets(word):
            if synset.pos() == pos_tag[0].lower():
                for lemma in synset.lemmas():
                    meanings.add(lemma.name())
        if len(meanings) > 1:
            ambiguous_words[word] = list(meanings)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File d:\sw\anaconda3\lib\site-packages\nltk\corpus\util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File d:\sw\anaconda3\lib\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource omw-1.4 not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('omw-1.4')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/omw-1.4.zip/omw-1.4/
#
#   Searched in:
#     - 'C:\\Users\\kunja/nltk_data'
#     - 'd:\\sw\\anaconda3\\nltk_data'
#     - 'd:\\sw\\anaconda3\\share\\nltk_data'
#     - 'd:\\sw\\anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\kunja\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[8], line 7
#       5 if pos_tag.startswith('V') or pos_tag.startswith('N'):
#       6     meanings = set()
# ----> 7     for synset in wordnet.synsets(word):
#       8         if synset.pos() == pos_tag[0].lower():
#       9             for lemma in synset.lemmas():
#
# File d:\sw\anaconda3\lib\site-packages\nltk\corpus\util.py:121, in LazyCorpusLoader.__getattr__(self, attr)
#     118 if attr == "__bases__":
#     119     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 121 self.__load()
#     122 # This looks circular, but its not, since __load() changes our
#     123 # __class__ to something new:
#     124 return getattr(self, attr)
#
# File d:\sw\anaconda3\lib\site-packages\nltk\corpus\util.py:89, in LazyCorpusLoader.__load(self)
#      86             raise e
#      88 # Load the corpus.
# ---> 89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#      91 # This is where the magic happens!  Transform ourselves into
#      92 # the corpus by modifying our own __dict__ and __class__ to
#      93 # match that of the corpus.
#      95 args, kwargs = self.__args, self.__kwargs
#
# File d:\sw\anaconda3\lib\site-packages\nltk\corpus\reader\wordnet.py:1176, in WordNetCorpusReader.__init__(self, root, omw_reader)
#    1172     warnings.warn(
#    1173         "The multilingual functions are not available with this Wordnet version"
#    1174     )
#    1175 else:
# -> 1176     self.provenances = self.omw_prov()
#    1178 # A cache to store the wordnet data of multiple languages
#    1179 self._lang_data = defaultdict(list)
#
# File d:\sw\anaconda3\lib\site-packages\nltk\corpus\reader\wordnet.py:1285, in WordNetCorpusReader.omw_prov(self)
#    1283 provdict = {}
#    1284 provdict["eng"] = ""
# -> 1285 fileids = self._omw_reader.fileids()
#    1286 for fileid in fileids:
#    1287     prov, langfile = os.path.split(fileid)
#
# File d:\sw\anaconda3\lib\site-packages\nltk\corpus\util.py:121, in LazyCorpusLoader.__getattr__(self, attr)
#     118 if attr == "__bases__":
#     119     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 121 self.__load()
#     122 # This looks circular, but its not, since __load() changes our
#     123 # __class__ to something new:
#     124 return getattr(self, attr)
#
# File d:\sw\anaconda3\lib\site-packages\nltk\corpus\util.py:86, in LazyCorpusLoader.__load(self)
#      84             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85         except LookupError:
# ---> 86             raise e
#      88 # Load the corpus.
#      89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File d:\sw\anaconda3\lib\site-packages\nltk\corpus\util.py:81, in LazyCorpusLoader.__load(self)
#      79 else:
#      80     try:
# ---> 81         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82     except LookupError as e:
#      83         try:
#
# File d:\sw\anaconda3\lib\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource omw-1.4 not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('omw-1.4')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/omw-1.4
#
#   Searched in:
#     - 'C:\\Users\\kunja/nltk_data'
#     - 'd:\\sw\\anaconda3\\nltk_data'
#     - 'd:\\sw\\anaconda3\\share\\nltk_data'
#     - 'd:\\sw\\anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\kunja\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
for i in ambiguous_words:
    print(i)
# Out:
# saw
# duck

# %%
# Generate all possible sentences by replacing ambiguous words
sentences = [sentence]
for word, meanings in ambiguous_words.items():
    new_sentences = []
    for meaning in meanings:
        for sentence in sentences:
            new_sentence = sentence.replace(word, meaning)
            new_sentences.append(new_sentence)
    sentences = new_sentences


for i in sentences:
    print(i)
# Out:
# I understand her duck's_egg
# I visualize her duck's_egg
# I get_a_line her duck's_egg
# I reckon her duck's_egg
# I pick_up her duck's_egg
# I figure her duck's_egg
# I envision her duck's_egg
# I regard her duck's_egg
# I assure her duck's_egg
# I consider her duck's_egg
# I realize her duck's_egg
# I get_wind her duck's_egg
# I see_to_it her duck's_egg
# I find her duck's_egg
# I hear her duck's_egg
# I watch her duck's_egg
# I insure her duck's_egg
# I visit her duck's_egg
# I take_care her duck's_egg
# I go_steady her duck's_egg
# I interpret her duck's_egg
# I experience her duck's_egg
# I meet her duck's_egg
# I determine her duck's_egg
# I examine her duck's_egg
# I get_word her duck's_egg
# I take_in her duck's_egg
# I find_out her duck's_egg
# I ensure her duck's_egg
# I encounter her duck's_egg
# I look her duck's_egg
# I catch her duck's_egg
# I attend her duck's_egg
# I check her duck's_egg
# I discover her duck's_egg
# I view her duck's_egg
# I run_into her duck's_egg
# I go_out her duck's_egg
# I go_through her duck's_egg
# I see her duck's_egg
# I visualise her duck's_egg
# I run_across her duck's_egg
# I control her duck's_egg
# I saw her duck's_egg
# I construe her duck's_egg
# I fancy her duck's_egg
# I witness her duck's_egg
# I picture her duck's_egg
# I image her duck's_egg
# I ascertain her duck's_egg
# I realise her duck's_egg
# I come_across her duck's_egg
# I escort her duck's_egg
# I date her duck's_egg
# I project her duck's_egg
# I learn her duck's_egg
# I understand her duck
# I visualize her duck
# I get_a_line her duck
# I reckon her duck
# I pick_up her duck
# I figure her duck
# I envision her duck
# I regard her duck
# I assure her duck
# I consider her duck
# I realize her duck
# I get_wind her duck
# I see_to_it her duck
# I find her duck
# I hear her duck
# I watch her duck
# I insure her duck
# I visit her duck
# I take_care her duck
# I go_steady her duck
# I interpret her duck
# I experience her duck
# I meet her duck
# I determine her duck
# I examine her duck
# I get_word her duck
# I take_in her duck
# I find_out her duck
# I ensure her duck
# I encounter her duck
# I look her duck
# I catch her duck
# I attend her duck
# I check her duck
# I discover her duck
# I view her duck
# I run_into her duck
# I go_out her duck
# I go_through her duck
# I see her duck
# I visualise her duck
# I run_across her duck
# I control her duck
# I saw her duck
# I construe her duck
# I fancy her duck
# I witness her duck
# I picture her duck
# I image her duck
# I ascertain her duck
# I realise her duck
# I come_across her duck
# I escort her duck
# I date her duck
# I project her duck
# I learn her duck

# %%
dataset = sentences

# %%
from nltk.tree import Tree

def validate_sentences(sentences, grammar_string):
    grammar = nltk.CFG.fromstring(grammar_string)
    for sentence in sentences:
        tokens = sentence.split()
        parser = nltk.ChartParser(grammar)
        trees = parser.parse(tokens)
        for tree in trees:
            print(f"Sentence: {sentence}")
            tree.pretty_print()

# %%
from nltk.chunk import RegexpParser
grammar = r"""
    NP: {<DT|PP\$>?<JJ>*<NN>}   # chunk determiner/possessive, adjectives and noun
        {<NNP>+}                # chunk sequences of proper nouns
        {<PRP>}
    VP: {<VB.*>+}               # chunk verbs and their modals
        {<JJ>*<RB>?<VB.*>+}     # chunk adverbs modifying the verb
    PP: {<IN><NP>}              # chunk prepositions followed by noun phrases
"""
validate_sentences(sentences, grammar)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File p:\python\lib\site-packages\nltk\grammar.py:1434, in read_grammar(input, nonterm_parser, probabilistic, encoding)
#    1432     else:
#    1433         # expand out the disjunctions on the RHS
# -> 1434         productions += _read_production(line, nonterm_parser, probabilistic)
#    1435 except ValueError as e:
#
# File p:\python\lib\site-packages\nltk\grammar.py:1338, in _read_production(line, nonterm_parser, probabilistic)
#    1337 if not m:
# -> 1338     raise ValueError("Expected an arrow")
#    1339 pos = m.end()
#
# ValueError: Expected an arrow
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# p:\College stuff\TY-1\SEM2\SP\SP CP\final.ipynb Cell 7 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> from nltk.chunk import RegexpParser
#       <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> grammar = r"""
#       <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a>     NP: {<DT|PP\$>?<JJ>*<NN>}   # chunk determiner/possessive, adjectives and noun
#       <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a>         {<NNP>+}                # chunk sequences of proper nouns
#    (...)
#       <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a>     PP: {<IN><NP>}              # chunk prepositions followed by noun phrases
#       <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a> """
# ---> <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a> validate_sentences(sentences, grammar)
#
# p:\College stuff\TY-1\SEM2\SP\SP CP\final.ipynb Cell 7 in validate_sentences(sentences, grammar_string)
#       <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> def validate_sentences(sentences, grammar_string):
# ----> <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a>     grammar = nltk.CFG.fromstring(grammar_string)
#       <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a>     for sentence in sentences:
#       <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a>         tokens = sentence.split()
#
# File p:\python\lib\site-packages\nltk\grammar.py:547, in CFG.fromstring(cls, input, encoding)
#     540 @classmethod
#     541 def fromstring(cls, input, encoding=None):
#     542     """
#     543     Return the grammar instance corresponding to the input string(s).
#     544
#     545     :param input: a grammar, either in the form of a string or as a list of strings.
#     546     """
# --> 547     start, productions = read_grammar(
#     548         input, standard_nonterm_parser, encoding=encoding
#     549     )
#     550     return cls(start, productions)
#
# File p:\python\lib\site-packages\nltk\grammar.py:1436, in read_grammar(input, nonterm_parser, probabilistic, encoding)
#    1434             productions += _read_production(line, nonterm_parser, probabilistic)
#    1435     except ValueError as e:
# -> 1436         raise ValueError(f"Unable to parse line {linenum + 1}: {line}\n{e}") from e
#    1438 if not productions:
#    1439     raise ValueError("No productions found!")
#
# ValueError: Unable to parse line 2: NP: {<DT|PP\$>?<JJ>*<NN>}   # chunk determiner/possessive, adjectives and noun
# Expected an arrow

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.chunk import RegexpParser

# define grammar for NP, VP, and PP chunking
grammar = r"""
  NP: {<DT>?<JJ>*<NN.*>+}      # chunk one or more adjectives and a noun
  VP: {<VB.*><NP|PP>*}         # chunk verb followed by optional NP/PP
  PP: {<IN><NP>}               # chunk preposition followed by NP
"""

# grammar = r"""
#   S -> NP VP
#   NP -> Det Nom | Pronoun | ProperNoun
#   Nom -> Adj Nom | Noun | PP
#   VP -> Verb NP | Verb NP PP | Verb PP | Verb Adverb
#   PP -> Preposition NP
#   Det -> 'the' | 'a' | 'an'
#   Pronoun -> 'i' | 'you' | 'he' | 'she' | 'it' | 'we' | 'they' | 'me' | 'him' | 'her' | 'us' | 'them'
#   ProperNoun -> 'John' | 'Mary' | 'London' | 'India'
#   Noun -> 'book' | 'table' | 'computer' | 'car' | 'music' | 'love'
#   Verb -> 'read' | 'write' | 'play' | 'drive' | 'listen' | 'love'
#   Adverb -> 'slowly' | 'quickly' | 'loudly' | 'happily' | 'sadly'
#   Adj -> 'red' | 'big' | 'happy' | 'small' | 'black' | 'white'
#   Preposition -> 'in' | 'on' | 'at' | 'with' | 'to' | 'from' | 'of'
# """



# create a RegexpParser with the grammar
parser = RegexpParser(grammar)

# example sentence
# sentence = "The big black cat sat on the windowsill"

for sentence in sentences:
    # tokenize the sentence
    tokens = word_tokenize(sentence)

    # POS tag the tokens
    pos_tags = nltk.pos_tag(tokens)

    # parse the POS tagged tokens using the RegexpParser
    tree = parser.parse(pos_tags)

    # print the tree
    # print(tree)

    Tree.fromstring(str(tree)).pretty_print()
# Out:
#          S
#    ______|_________________________
#   |      |          VP             NP
#   |      |          |              |
# I/PRP her/PRP understand/VBP duck's_egg/NN
#
#          S
#    ______|________________________
#   |      |          VP            NP
#   |      |          |             |
# I/PRP her/PRP visualize/VBP duck's_egg/NN
#
#          S
#    ______|_________________________
#   |      |          VP             NP
#   |      |          |              |
# I/PRP her/PRP get_a_line/VBP duck's_egg/NN
#
#          S
#    ______|_____________________
#   |      |        VP           NP
#   |      |        |            |
# I/PRP her/PRP reckon/VBP duck's_egg/NN
#
#          S
#    ______|______________________
#   |      |         VP           NP
#   |      |         |            |
# I/PRP her/PRP pick_up/VBP duck's_egg/NN
#
#          S
#    ______|______________________
#   |      |         VP           NP
#   |      |         |            |
# I/PRP her/PRP$ figure/VBP duck's_egg/NN
#
#          S
#    ______|_______________________
#   |      |         VP            NP
#   |      |         |             |
# I/PRP her/PRP envision/VBP duck's_egg/NN
#
#          S
#    ______|_____________________
#   |      |        VP           NP
#   |      |        |            |
# I/PRP her/PRP regard/VBP duck's_egg/NN
#
#          S
#    ______|______________________
#   |      |         VP           NP
#   |      |         |            |
# I/PRP her/PRP$ assure/VBP duck's_egg/NN
#
#          S
#    ______|_______________________
#   |      |         VP            NP
#   |      |         |             |
# I/PRP her/PRP consider/VBP duck's_egg/NN
#
#          S
#    ______|______________________
#   |      |         VP           NP
#   |      |         |            |
# I/PRP her/PRP realize/VBP duck's_egg/NN
#
#          S
#    ______|_______________________
#   |      |         VP            NP
#   |      |         |             |
# I/PRP her/PRP get_wind/VBP duck's_egg/NN
#
#          S
#    ______|________________________
#   |      |          VP            NP
#   |      |          |             |
# I/PRP her/PRP see_to_it/VBP duck's_egg/NN
#
#          S
#    ______|___________________
#   |      |       VP          NP
#   |      |       |           |
# I/PRP her/PRP find/VBP duck's_egg/NN
#
#          S
#    ______|___________________
#   |      |       VP          NP
#   |      |       |           |
# I/PRP her/PRP hear/VBP duck's_egg/NN
#
#          S
#    ______|____________________
#   |      |        VP          NP
#   |      |        |           |
# I/PRP her/PRP watch/VBP duck's_egg/NN
#
#          S
#    ______|______________________
#   |      |         VP           NP
#   |      |         |            |
# I/PRP her/PRP$ insure/VBP duck's_egg/NN
#
#          S
#    ______|____________________
#   |      |        VP          NP
#   |      |        |           |
# I/PRP her/PRP visit/VBP duck's_egg/NN
#
#          S
#    ______|________________________
#   |      |          VP            NP
#   |      |          |             |
# I/PRP her/PRP take_care/VBP duck's_egg/NN
#
#          S
#    ______|________________________
#   |      |          VP            NP
#   |      |          |             |
# I/PRP her/PRP go_steady/VBP duck's_egg/NN
#
#          S
#    ______|________________________
#   |      |          VP            NP
#   |      |          |             |
# I/PRP her/PRP interpret/VBP duck's_egg/NN
#
#          S
#    ______|_________________________
#   |      |          VP             NP
#   |      |          |              |
# I/PRP her/PRP experience/VBP duck's_egg/NN
#
#          S
#    ______|___________________
#   |      |       VP          NP
#   |      |       |           |
# I/PRP her/PRP meet/VBP duck's_egg/NN
#
#          S
#    ______|________________________
#   |      |          VP            NP
#   |      |          |             |
# I/PRP her/PRP determine/VBP duck's_egg/NN
#
#          S
#    ______|______________________
#   |      |         VP           NP
#   |      |         |            |
# I/PRP her/PRP examine/VBP duck's_egg/NN
#
#          S
#    ______|_______________________
#   |      |         VP            NP
#   |      |         |             |
# I/PRP her/PRP get_word/VBP duck's_egg/NN
#
#          S
#    ______|______________________
#   |      |         VP           NP
#   |      |         |            |
# I/PRP her/PRP take_in/VBP duck's_egg/NN
#
#          S
#    ______|_______________________
#   |      |         VP            NP
#   |      |         |             |
# I/PRP her/PRP find_out/VBP duck's_egg/NN
#
#          S
#    ______|____________________
#   |      |        VP          NP
#   |      |        |           |
# I/PRP her/PRP ensure/VB duck's_egg/NN
#
#          S
#    ______|________________________
#   |      |          VP            NP
#   |      |          |             |
# I/PRP her/PRP encounter/VBP duck's_egg/NN
#
#          S
#    ______|____________________
#   |      |        VP          NP
#   |      |        |           |
# I/PRP her/PRP$ look/VBP duck's_egg/NN
#
#          S
#    ______|____________________
#   |      |        VP          NP
#   |      |        |           |
# I/PRP her/PRP catch/VBP duck's_egg/NN
#
#          S
#    ______|_____________________
#   |      |        VP           NP
#   |      |        |            |
# I/PRP her/PRP attend/VBP duck's_egg/NN
#
#          S
#    ______|____________________
#   |      |        VP          NP
#   |      |        |           |
# I/PRP her/PRP check/VBP duck's_egg/NN
#
#          S
#    ______|_______________________
#   |      |         VP            NP
#   |      |         |             |
# I/PRP her/PRP discover/VBP duck's_egg/NN
#
#          S
#    ______|___________________
#   |      |       VP          NP
#   |      |       |           |
# I/PRP her/PRP view/VBP duck's_egg/NN
#
#          S
#    ______|_______________________
#   |      |         VP            NP
#   |      |         |             |
# I/PRP her/PRP run_into/VBP duck's_egg/NN
#
#          S
#    ______|_____________________
#   |      |        VP           NP
#   |      |        |            |
# I/PRP her/PRP go_out/VBP duck's_egg/NN
#
#          S
#    ______|_________________________
#   |      |          VP             NP
#   |      |          |              |
# I/PRP her/PRP go_through/VBP duck's_egg/NN
#
#          S
#    ______|__________________
#   |      |       VP         NP
#   |      |       |          |
# I/PRP her/PRP see/VBP duck's_egg/NN
#
#          S
#    ______|________________________
#   |      |          VP            NP
#   |      |          |             |
# I/PRP her/PRP visualise/VBP duck's_egg/NN
#
#          S
#    ______|_________________________
#   |      |          VP             NP
#   |      |          |              |
# I/PRP her/PRP run_across/VBP duck's_egg/NN
#
#          S
#    ______|______________________
#   |      |         VP           NP
#   |      |         |            |
# I/PRP her/PRP control/VBP duck's_egg/NN
#
#          S
#    ______|__________________
#   |      |       VP         NP
#   |      |       |          |
# I/PRP her/PRP saw/VBD duck's_egg/NN
#
#          S
#    ______|_______________________
#   |      |         VP            NP
#   |      |         |             |
# I/PRP her/PRP construe/VBP duck's_egg/NN
#
#          S
#    ______|____________________
#   |      |        VP          NP
#   |      |        |           |
# I/PRP her/PRP fancy/VBP duck's_egg/NN
#
#          S
#    ______|______________________
#   |      |         VP           NP
#   |      |         |            |
# I/PRP her/PRP witness/VBP duck's_egg/NN
#
#          S
#    ______|_______________________
#   |      |          VP           NP
#   |      |          |            |
# I/PRP her/PRP$ picture/VBP duck's_egg/NN
#
#          S
#    ______|___________________
#   |      |       NP          NP
#   |      |       |           |
# I/PRP her/PRP image/NN duck's_egg/NN
#
#          S
#    ______|________________________
#   |      |          VP            NP
#   |      |          |             |
# I/PRP her/PRP ascertain/VBP duck's_egg/NN
#
#          S
#    ______|______________________
#   |      |         VP           NP
#   |      |         |            |
# I/PRP her/PRP realise/VBP duck's_egg/NN
#
#          S
#    ______|__________________________
#   |      |           VP             NP
#   |      |           |              |
# I/PRP her/PRP come_across/VBP duck's_egg/NN
#
#          S
#    ______|_____________________
#   |      |        VP           NP
#   |      |        |            |
# I/PRP her/PRP escort/VBP duck's_egg/NN
#
#          S
#    ______|__________________
#   |      |       NP         NP
#   |      |       |          |
# I/PRP her/PRP date/NN duck's_egg/NN
#
#          S
#    ______|______________________
#   |      |         VP           NP
#   |      |         |            |
# I/PRP her/PRP project/VBP duck's_egg/NN
#
#          S
#    ______|____________________
#   |      |        VP          NP
#   |      |        |           |
# I/PRP her/PRP learn/VBP duck's_egg/NN
#
#          S
#    ______|______________________
#   |      |          VP          NP
#   |      |          |           |
# I/PRP her/PRP understand/VBP duck/NN
#
#          S
#    ______|_____________________
#   |      |          VP         NP
#   |      |          |          |
# I/PRP her/PRP visualize/VBP duck/NN
#
#          S
#    ______|______________________
#   |      |          VP          NP
#   |      |          |           |
# I/PRP her/PRP get_a_line/VBP duck/NN
#
#          S
#    ______|__________________
#   |      |        VP        NP
#   |      |        |         |
# I/PRP her/PRP reckon/VBP duck/NN
#
#          S
#    ______|___________________
#   |      |         VP        NP
#   |      |         |         |
# I/PRP her/PRP pick_up/VBP duck/NN
#
#          S
#    ______|___________________
#   |      |         VP        NP
#   |      |         |         |
# I/PRP her/PRP$ figure/VBP duck/NN
#
#          S
#    ______|____________________
#   |      |         VP         NP
#   |      |         |          |
# I/PRP her/PRP envision/VBP duck/NN
#
#          S
#    ______|__________________
#   |      |        VP        NP
#   |      |        |         |
# I/PRP her/PRP regard/VBP duck/NN
#
#          S
#    ______|___________________
#   |      |         VP        NP
#   |      |         |         |
# I/PRP her/PRP$ assure/VBP duck/NN
#
#          S
#    ______|____________________
#   |      |         VP         NP
#   |      |         |          |
# I/PRP her/PRP consider/VBP duck/NN
#
#          S
#    ______|___________________
#   |      |         VP        NP
#   |      |         |         |
# I/PRP her/PRP realize/VBP duck/NN
#
#          S
#    ______|____________________
#   |      |         VP         NP
#   |      |         |          |
# I/PRP her/PRP get_wind/VBP duck/NN
#
#          S
#    ______|_____________________
#   |      |          VP         NP
#   |      |          |          |
# I/PRP her/PRP see_to_it/VBP duck/NN
#
#          S
#    ______|________________
#   |      |       VP       NP
#   |      |       |        |
# I/PRP her/PRP find/VBP duck/NN
#
#          S
#    ______|________________
#   |      |       VP       NP
#   |      |       |        |
# I/PRP her/PRP hear/VBP duck/NN
#
#          S
#    ______|_________________
#   |      |        VP       NP
#   |      |        |        |
# I/PRP her/PRP watch/VBP duck/NN
#
#          S
#    ______|___________________
#   |      |         VP        NP
#   |      |         |         |
# I/PRP her/PRP$ insure/VBP duck/NN
#
#          S
#    ______|_________________
#   |      |        VP       NP
#   |      |        |        |
# I/PRP her/PRP visit/VBP duck/NN
#
#          S
#    ______|_____________________
#   |      |          VP         NP
#   |      |          |          |
# I/PRP her/PRP take_care/VBP duck/NN
#
#          S
#    ______|_____________________
#   |      |          VP         NP
#   |      |          |          |
# I/PRP her/PRP go_steady/VBP duck/NN
#
#          S
#    ______|_____________________
#   |      |          VP         NP
#   |      |          |          |
# I/PRP her/PRP interpret/VBP duck/NN
#
#          S
#    ______|______________________
#   |      |          VP          NP
#   |      |          |           |
# I/PRP her/PRP experience/VBP duck/NN
#
#          S
#    ______|________________
#   |      |       VP       NP
#   |      |       |        |
# I/PRP her/PRP meet/VBP duck/NN
#
#          S
#    ______|_____________________
#   |      |          VP         NP
#   |      |          |          |
# I/PRP her/PRP determine/VBP duck/NN
#
#          S
#    ______|___________________
#   |      |         VP        NP
#   |      |         |         |
# I/PRP her/PRP examine/VBP duck/NN
#
#          S
#    ______|____________________
#   |      |         VP         NP
#   |      |         |          |
# I/PRP her/PRP get_word/VBP duck/NN
#
#          S
#    ______|___________________
#   |      |         VP        NP
#   |      |         |         |
# I/PRP her/PRP take_in/VBP duck/NN
#
#          S
#    ______|____________________
#   |      |         VP         NP
#   |      |         |          |
# I/PRP her/PRP find_out/VBP duck/NN
#
#          S
#    ______|_________________
#   |      |        VP       NP
#   |      |        |        |
# I/PRP her/PRP ensure/VB duck/NN
#
#          S
#    ______|_____________________
#   |      |          VP         NP
#   |      |          |          |
# I/PRP her/PRP encounter/VBP duck/NN
#
#          S
#    ______|_________________
#   |      |        VP       NP
#   |      |        |        |
# I/PRP her/PRP$ look/VBP duck/NN
#
#          S
#    ______|_________________
#   |      |        VP       NP
#   |      |        |        |
# I/PRP her/PRP catch/VBP duck/NN
#
#          S
#    ______|__________________
#   |      |        VP        NP
#   |      |        |         |
# I/PRP her/PRP attend/VBP duck/NN
#
#          S
#    ______|_________________
#   |      |        VP       NP
#   |      |        |        |
# I/PRP her/PRP check/VBP duck/NN
#
#          S
#    ______|____________________
#   |      |         VP         NP
#   |      |         |          |
# I/PRP her/PRP discover/VBP duck/NN
#
#          S
#    ______|________________
#   |      |       VP       NP
#   |      |       |        |
# I/PRP her/PRP view/VBP duck/NN
#
#          S
#    ______|____________________
#   |      |         VP         NP
#   |      |         |          |
# I/PRP her/PRP run_into/VBP duck/NN
#
#          S
#    ______|__________________
#   |      |        VP        NP
#   |      |        |         |
# I/PRP her/PRP go_out/VBP duck/NN
#
#          S
#    ______|______________________
#   |      |          VP          NP
#   |      |          |           |
# I/PRP her/PRP go_through/VBP duck/NN
#
#          S
#    ______|_______________
#   |      |       VP      NP
#   |      |       |       |
# I/PRP her/PRP see/VBP duck/NN
#
#          S
#    ______|_____________________
#   |      |          VP         NP
#   |      |          |          |
# I/PRP her/PRP visualise/VBP duck/NN
#
#          S
#    ______|______________________
#   |      |          VP          NP
#   |      |          |           |
# I/PRP her/PRP run_across/VBP duck/NN
#
#          S
#    ______|___________________
#   |      |         VP        NP
#   |      |         |         |
# I/PRP her/PRP control/VBP duck/NN
#
#          S
#    ______|_______________
#   |      |       VP      NP
#   |      |       |       |
# I/PRP her/PRP saw/VBD duck/NN
#
#          S
#    ______|____________________
#   |      |         VP         NP
#   |      |         |          |
# I/PRP her/PRP construe/VBP duck/NN
#
#          S
#    ______|_________________
#   |      |        VP       NP
#   |      |        |        |
# I/PRP her/PRP fancy/VBP duck/NN
#
#          S
#    ______|___________________
#   |      |         VP        NP
#   |      |         |         |
# I/PRP her/PRP witness/VBP duck/NN
#
#          S
#    ______|____________________
#   |      |          VP        NP
#   |      |          |         |
# I/PRP her/PRP$ picture/VBP duck/NN
#
#          S
#    ______|________________
#   |      |       NP       NP
#   |      |       |        |
# I/PRP her/PRP image/NN duck/NN
#
#          S
#    ______|_____________________
#   |      |          VP         NP
#   |      |          |          |
# I/PRP her/PRP ascertain/VBP duck/NN
#
#          S
#    ______|___________________
#   |      |         VP        NP
#   |      |         |         |
# I/PRP her/PRP realise/VBP duck/NN
#
#          S
#    ______|_______________________
#   |      |           VP          NP
#   |      |           |           |
# I/PRP her/PRP come_across/VBP duck/NN
#
#          S
#    ______|__________________
#   |      |        VP        NP
#   |      |        |         |
# I/PRP her/PRP escort/VBP duck/NN
#
#          S
#    ______|_______________
#   |      |       NP      NP
#   |      |       |       |
# I/PRP her/PRP date/NN duck/NN
#
#          S
#    ______|___________________
#   |      |         VP        NP
#   |      |         |         |
# I/PRP her/PRP project/VBP duck/NN
#
#          S
#    ______|_________________
#   |      |        VP       NP
#   |      |        |        |
# I/PRP her/PRP learn/VBP duck/NN

# %%
import nltk

# grammar = ('''
#     NP: {<NNP><VBZ|VBD><DT><JJ>*<NN><.>} # NP
#     ''')

grammar = r"""
    NP: {<DT>?<JJ>*<NN.*>+}       # noun phrase
    VP: {<VB.*><NP|PP>*}          # verb phrase
    PP: {<IN><NP>}                # prepositional phrase
    ADJ: {<JJ.*>}                 # adjective
    ADV: {<RB.*>}                 # adverb
    CONJ: {<CC>}                  # conjunction
    PUNC: {<\.|,|:|''|\(``|\)|\$>}  # punctuation
    # Define sentence patterns
    S: {<NP><VP>}                 # simple sentence
    
"""


sentences = [
    "Mary had a little lamb.",
    "John has a cute black pup.",
    "I ate five apples.",
    "I saw her duck",
]

def has_noun_phrase(sentence):
    parsed = chunkParser.parse(pos_tag(word_tokenize(sentence)))
    for subtree in parsed:
        if type(subtree) == nltk.Tree and subtree.label() == 'NP':
            return True
    return False

chunkParser = nltk.RegexpParser(grammar)
for sentence in sentences:
    print(has_noun_phrase(sentence))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# p:\College stuff\TY-1\SEM2\SP\SP CP\final.ipynb Cell 10 in <cell line: 36>()
#      <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X22sZmlsZQ%3D%3D?line=34'>35</a> chunkParser = nltk.RegexpParser(grammar)
#      <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X22sZmlsZQ%3D%3D?line=35'>36</a> for sentence in sentences:
# ---> <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X22sZmlsZQ%3D%3D?line=36'>37</a>     print(has_noun_phrase(sentence))
#
# p:\College stuff\TY-1\SEM2\SP\SP CP\final.ipynb Cell 10 in has_noun_phrase(sentence)
#      <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X22sZmlsZQ%3D%3D?line=27'>28</a> def has_noun_phrase(sentence):
# ---> <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X22sZmlsZQ%3D%3D?line=28'>29</a>     parsed = chunkParser.parse(pos_tag(word_tokenize(sentence)))
#      <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X22sZmlsZQ%3D%3D?line=29'>30</a>     for subtree in parsed:
#      <a href='vscode-notebook-cell:/p%3A/College%20stuff/TY-1/SEM2/SP/SP%20CP/final.ipynb#X22sZmlsZQ%3D%3D?line=30'>31</a>         if type(subtree) == nltk.Tree and subtree.label() == 'NP':
#
# TypeError: 'str' object is not callable
